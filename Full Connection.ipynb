# %%
from IPython.display import Image
Image(filename='C:/Users/Admin/Pictures/full1.png') 

#Full Connection :

# %%
from IPython.display import Image
Image(filename='C:/Users/Admin/Pictures/full2.png')

# %%
from IPython.display import Image
Image(filename='C:/Users/Admin/Pictures/full_cat.png')

# %%
# upar wale se yeh seekhega ki,
# mera yeh sab neuron ka probab high hai, toh inpe hi bharosa, 
# agli baar inko hi dekhna hai jyada .

# %%
from IPython.display import Image
Image(filename='C:/Users/Admin/Pictures/full_dog1.png')

# %%
# Ab , agli baar koi photo dikhau isko, toh 
# unhi neuron pe jyada bharosa kr ke, probab high nikaal ke , prediction done..

# %%
from IPython.display import Image
Image(filename='C:/Users/Admin/Pictures/full_conction_dog.png')

# %%
from IPython.display import Image
Image(filename='C:/Users/Admin/Pictures/full_co_cat.png')
