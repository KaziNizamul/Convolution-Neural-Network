# %% [markdown]
# ### SoftMax Function ( formula ):

# %%
from IPython.display import Image
Image(filename="C:/Users/Admin/Pictures/softmax.png")

# #KYUN SOFTMAX ? 
# Answer : Kaise pata chalta hain system ko ki , sab mila ke sum=1 laana hain?
#         isliye softmax function se pass krwate hain.

# Formula :

# %% [markdown]
# ###  Cross Entropy formula for errors:

# %%
from IPython.display import Image
Image(filename="C:/Users/Admin/Pictures/ce2.png")

# %%
from IPython.display import Image
Image(filename="C:/Users/Admin/Pictures/ce_eg1.png")


# Example :

# %%
from IPython.display import Image
Image(filename="C:/Users/Admin/Pictures/ce_eg2.png")

# %%
toh ab toh mean squared accha hona chahiye ?
Answer : lets say main 0.00001 pe hu , aur 1 pe jaana hain mereko.
         So, next time jab  main improve kiya toh , 
         0.0001 pe pahuchunga, ... next time 0.001 pe ( Kyunki Log ke term mein improvment ho rha hai.)
            
        But Mean Squared Barbaad kr dega .
        Mean squared se , negligible improvement dikhega. 
        
        Isliye, Cross entropy.
